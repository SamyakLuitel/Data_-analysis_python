# %% [markdown]
# # Pandas

# %% [markdown]
# ## manual data loading

# %%
x =[]

# %%
import numpy as np

# %%
 for line in open("data.csv"):
    row = line.split(",") 
    x.append(row)

# %%
x
# Out:
# [['17.9302012052', '94.5205919533', '320.259529602\n'],
#  ['97.1446971852', '69.5932819844', '404.634471526\n'],
#  ['81.7759007845', '5.73764809688', '181.485107741\n'],
#  ['55.8543424175', '70.3259016768', '321.773638018\n'],
#  ['49.3665499855', '75.1140401571', '322.465485583\n'],
#  ['3.19270246506', '29.2562988631', '94.6188108954\n'],
#  ['49.2007840582', '86.1444385075', '356.348092747\n'],
#  ['21.882803904', '46.8415051959', '181.653769226\n'],
#  ['79.5098627219', '87.397355535', '423.557743194\n'],
#  ['88.1538874975', '65.2056419279', '369.229245443\n'],
#  ['60.7438543399', '99.9576339008', '427.605803661\n'],
#  ['67.4155819451', '50.3683096094', '292.471821553\n'],
#  ['48.3181157719', '99.1289531425', '395.529811407\n'],
#  ['28.8299719729', '87.1849488537', '319.031348455\n'],
#  ['43.853742664', '64.4736390798', '287.4281441\n'],
#  ['25.3136940868', '83.5452942552', '292.768908839\n'],
#  ['10.807726675', '45.6955685904', '159.663307674\n'],
# ...

# %%
x = np.array(x)

# %%
x
# Out:
# array([['17.9302012052', '94.5205919533', '320.259529602\n'],
#        ['97.1446971852', '69.5932819844', '404.634471526\n'],
#        ['81.7759007845', '5.73764809688', '181.485107741\n'],
#        ['55.8543424175', '70.3259016768', '321.773638018\n'],
#        ['49.3665499855', '75.1140401571', '322.465485583\n'],
#        ['3.19270246506', '29.2562988631', '94.6188108954\n'],
#        ['49.2007840582', '86.1444385075', '356.348092747\n'],
#        ['21.882803904', '46.8415051959', '181.653769226\n'],
#        ['79.5098627219', '87.397355535', '423.557743194\n'],
#        ['88.1538874975', '65.2056419279', '369.229245443\n'],
#        ['60.7438543399', '99.9576339008', '427.605803661\n'],
#        ['67.4155819451', '50.3683096094', '292.471821553\n'],
#        ['48.3181157719', '99.1289531425', '395.529811407\n'],
#        ['28.8299719729', '87.1849488537', '319.031348455\n'],
#        ['43.853742664', '64.4736390798', '287.4281441\n'],
# ...

# %%
x.shape
# Out:
# (100, 3)

# %% [markdown]
# # Data Frames

# %%
import pandas as pd

# %%
x = pd.read_csv("data.csv", header=None)

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# 0    100 non-null float64
# 1    100 non-null float64
# 2    100 non-null float64
# dtypes: float64(3)
# memory usage: 2.5 KB

# %%
x.head()
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486

# %%
x.head(10)
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486
# 5   3.192702  29.256299   94.618811
# 6  49.200784  86.144439  356.348093
# 7  21.882804  46.841505  181.653769
# 8  79.509863  87.397356  423.557743
# 9  88.153887  65.205642  369.229245

# %% [markdown]
# # selecting rows and columns

# %%
M = x.as_matrix()
# Out:
# /home/samyak/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
type(M)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# 0     17.930201
# 1     97.144697
# 2     81.775901
# 3     55.854342
# 4     49.366550
#         ...
# 95    46.456779
# 96    77.130301
# 97    68.600608
# 98    41.693887
# 99     4.142669
# Name: 0, Length: 100, dtype: float64

# %% [markdown]
# In numpy:x[0]-> 0th row
#
# In pandas:x[0]-> column that has name 0

# %%
type(x[0])
# Out:
# pandas.core.series.Series

# %%
# for 0th row 
x.iloc[0]
# Out:
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
x.ix[0]
# Out:
# /home/samyak/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
x[0][2]
# Out:
# 81.7759007845

# %%
x[[0,2]]
# Out:
#             0           2
# 0   17.930201  320.259530
# 1   97.144697  404.634472
# 2   81.775901  181.485108
# 3   55.854342  321.773638
# 4   49.366550  322.465486
# ..        ...         ...
# 95  46.456779  336.876154
# 96  77.130301  438.460586
# 97  68.600608  355.900287
# 98  41.693887  284.834637
# 99   4.142669  168.034401
#
# [100 rows x 2 columns]

# %%
x[ x[0]<5]
# Out:
#            0          1           2
# 5   3.192702  29.256299   94.618811
# 44  3.593966  96.252217  293.237183
# 54  4.593463  46.335932  145.818745
# 90  1.382983  84.944087  252.905653
# 99  4.142669  52.254726  168.034401

# %%
x[0]<5
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99     True
# Name: 0, Length: 100, dtype: bool

# %% [markdown]
# # data frames : Column name

# %%
import pandas as pd

# %%
df = pd.read_csv("international-airline-passengers.csv", engine = "python", skipfooter=3)

# %%
df.columns
# Out:
# Index(['Month', 'International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60'], dtype='object')

# %%
df.columns =["month","passengers"]

# %%
df.columns
# Out:
# Index(['month', 'passengers'], dtype='object')

# %%
df["passengers"]
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %%
df.passengers
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %% [markdown]
# # adding columns

# %%
df["ones"]=1

# %%
df.head()
# Out:
#      month  passengers  ones
# 0  1949-01         112     1
# 1  1949-02         118     1
# 2  1949-03         132     1
# 3  1949-04         129     1
# 4  1949-05         121     1

# %% [markdown]
# # apply functions
#
# what if we want to assign new columns value where each cell is derived from the values already in its row?
#
# we use the apply funtion
#
# df[ "x1x2" ] =df.apply(lambda row: row["x1"] * row ["x2"] , axis=1

# %%
from datetime import datetime

# %% [markdown]
# datetime.strptime("1949-05","%Y-%m")

# %%
df["dt"] = df.apply(lambda row: datetime.strptime(row["month"],"%Y-%m"),axis =1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 4 columns):
# month         144 non-null object
# passengers    144 non-null int64
# ones          144 non-null int64
# dt            144 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 4.6+ KB

# %% [markdown]
# # joins

# %%
import pandas as pd

# %%
t1 = pd.read_csv("table1.csv")
t2 = pd.read_csv('table2.csv')

# %%
t1
# Out:
#    user_id            email  age
# 0        1  alice@gmail.com   20
# 1        2    bob@gmail.com   25
# 2        3  carol@gmail.com   30

# %%
t2
# Out:
#     user_id  ad_id  click
# 0         1      1      1
# 1         1      2      0
# 2         1      5      0
# 3         2      3      0
# 4         2      4      1
# 5         2      1      0
# 6         3      2      0
# 7         3      1      0
# 8         3      3      0
# 9         3      4      0
# 10        3      5      1

# %%
m = pd.merge(t1,t2, on ="user_id")

# %%
m
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1

# %%
t1.merge(t2, on = "user_id")
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1

# %% [markdown]
# ## values vs matrix

# %%
import pandas as pd 
import numpy as np
df = pd.DataFrame([[1,2],[3,4]])

# %%
df
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
df.as_matrix()
# Out:
# /home/samyak/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[1, 2],
#        [3, 4]])

# %%
df.values
# Out:
# array([[1, 2],
#        [3, 4]])
